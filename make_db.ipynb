# %%
import pandas as pd
import json
import sqlite3
from update_db_func import *
from sqlalchemy import create_engine

# %%
df=pd.read_csv('MOF.csv')
df=df.rename(columns={'Unnamed: 0': 'date'})

# %%
db_file_name=r'china_mof.db'
db_table_name = r'financial_data'
unique_keys = ['date']
engine = create_engine(f'sqlite:///{db_file_name}')

# create_db(engine, db_table_name, df, unique_keys)
create_update_db(engine, db_table_name, df, unique_keys)
# Out:
# Table 'financial_data' exists.
# ✨ No changes found.

# %%
df=pd.read_csv('PBOC_Money_Supply.csv')
df=df.rename(columns={'0': 'date'})
df['updated_at'] = pd.Timestamp.now().strftime('%Y-%m-%d %H:%M:%S')

# %%
db_file_name=r'PBOC.db'
db_table_name = r'money_supply'
unique_keys = ['date']
engine = create_engine(f'sqlite:///{db_file_name}')
create_update_db(engine, db_table_name, df, unique_keys)
# Out:
# Table 'money_supply' exists.
# ✅ Successfully synced 1 rows (handled special characters).

# %%
df=pd.read_csv('PBOC_Balance_Sheet.csv')
df=df.rename(columns={'Unnamed: 0': 'date'})
df['updated_at'] = pd.Timestamp.now().strftime('%Y-%m-%d %H:%M:%S')

# %%
db_file_name=r'PBOC.db'
db_table_name = r'balance_sheet'
unique_keys = ['date']
engine = create_engine(f'sqlite:///{db_file_name}')
create_update_db(engine, db_table_name, df, unique_keys)
# Out:
# Table 'balance_sheet' exists.
# ✅ Successfully synced 12 rows (handled special characters).
